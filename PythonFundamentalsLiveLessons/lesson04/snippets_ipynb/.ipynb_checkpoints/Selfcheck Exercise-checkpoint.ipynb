# %% [markdown]
# # Selfcheck Exercise

# %% [markdown]
# #### Ex 4.2

# %% [markdown]
# ##### Define a function square_root that receives a number as a parameter and returns the square root of that number. Determine the square root of 6.25.

# %%
def square_root(number):
    return number ** 0.5
    
square_root(6.25)
# Out:
# 2.5

# %% [markdown]
# #### Ex 4.3

# %% [markdown]
# ##### Call function `max` with the list `[14, 27, 5, 3]` as an argument, then call function `min` with the string `'orange'` as an argument.

# %%
max([14, 27, 5, 3])
# Out:
# 27

# %%
min("orange")
# Out:
# 'a'

# %% [markdown]
# #### Ex 4.4

# %% [markdown]
# ##### Requirements statement: Use a `for` statement, `randrange` and a conditional expression (introduced in the preceding chapter) to simulate 20 coin flips, displaying `H` for heads and `T` for tails all on the same line, each separated by a space.

# %%
import random

for i in range(20):
    print('H' if random.randrange(2) == 0 else 'T', end=' ')
# Out:
# H T T H H T T H H H H H H T H T T H H T

# %% [markdown]
# #### Ex 4.5

# %% [markdown]
# ##### Pack a student tuple with the name 'Sue' and the list [89, 94, 85], display the tuple, then unpack it into variables name and grades, and display their values.

# %%
student = ('Sue', [89, 94, 85])

# %%
student
# Out:
# ('Sue', [89, 94, 85])

# %%
name, grades = student

# %%
print(f'{name}: {grades}')
# Out:
# Sue: [89, 94, 85]

# %% [markdown]
# #### Ex 4.11

# %% [markdown]
# ##### Create a function named calculate_product that receives an arbitrary argument list and returns the product of all the arguments. Call the function with the arguments 10, 20 and 30 then with the sequence of integers produced by range(1, 6, 2).

# %%
def calculate_product(*args):
    product = 1
    for value in args:
        product *= value
    return product

# %%
calculate_product(10, 20, 30)
# Out:
# 6000

# %%
calculate_product(*range(1, 6, 2))
# Out:
# 15

# %% [markdown]
# #### Ex 4.14

# %% [markdown]
# ##### Import the decimal module with the shorthand name dec, then create a Decimal object with the value 2.5 and square its value.

# %%
import decimal as dec

dec.Decimal('2.5') ** 2
# Out:
# Decimal('6.25')

# %% [markdown]
# #### Ex 4.15

# %% [markdown]
# ##### Create a variable width with the value 15.5, then show that modifying the variable creates a new object. Display width’s identity and value before and after modifying its value.

# %%
width = 15.5

print('id:', id(width), ' value:', width)
# Out:
# id: 126455006095120  value: 15.5

# %%
width *= 3 

print('id:', id(width), ' value:', width)
# Out:
# id: 126455440902672  value: 46.5
