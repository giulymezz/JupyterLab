# %% [markdown]
# # Selfcheck Exercise

# %% [markdown]
# #### Ex 8.2.1

# %% [markdown]
# ##### Use the type specifier `c` to display the characters that correspond to the character codes 58, 45 and 41.

# %%
print(f"{58:c}{45:c}{41:c}")
# Out:
# :-)

# %% [markdown]
# #### Ex 8.2.2

# %% [markdown]
# ##### Display on separate lines the name 'Amanda' right-, center- and left-aligned in a field of 10 characters. Enclose each result in brackets so you can see the alignment results more clearly.

# %%
print(f'[{"Amanda":>10}]\n[{"Amanda":^10}]\n[{"Amanda":<10}]')
# Out:
# [    Amanda]
# [  Amanda  ]
# [Amanda    ]

# %% [markdown]
# #### Ex 8.2.3

# %% [markdown]
# ##### Print the values `10240.473` and `-3210.9521`, each preceded by its sign in 10-character fields with thousands separators, their decimal points aligned vertically and two digits of precision.

# %%
print(f'{10240.473:+10,.2f}\n{-3210.9521:+10,.2f}')
# Out:
# +10,240.47
#  -3,210.95

# %% [markdown]
# #### Ex 8.2.4

# %% [markdown]
# ##### Use string method `format` to reimplement the IPython sessions in the Self Check exercises from Sections 8.2.1–8.2.3.

# %%
print(f"{58:c}{45:c}{41:c}")
print(f'[{"Amanda":>10}]\n[{"Amanda":^10}]\n[{"Amanda":<10}]')
print(f'{10240.473:+10,.2f}\n{-3210.9521:+10,.2f}')
# Out:
# :-)

# %% [markdown]
# Ex. 8.2.1

# %%
print('{:c} {:c} {:c}'.format(58, 45, 41))
# Out:
# : - )

# %% [markdown]
# Ex. 8.2.2

# %%
print('[{0:>10}]\n[{0:^10}]\n[{0:<10}]'.format("Amanda"))
# Out:
# [    Amanda]
# [  Amanda  ]
# [Amanda    ]

# %%
print('{:+10,.2f}\n{:+10,.2f}'.format(10240.473, -3210.9521))
# Out:
# +10,240.47
#  -3,210.95

# %% [markdown]
# #### Ex 8.3

# %% [markdown]
# ##### Use the `+=` operator to concatenate your first and last name. Then use the `*=` operator to create a bar of asterisks with the same number of characters as your full name and display the bar above and below your name.

# %%
name = "Giulia"
name += " Mazzi"
name
# Out:
# 'Giulia Mazzi'

# %%
bar = '*'
bar *= len(name)
bar
# Out:
# '************'

# %%
print(f'{bar}\n{name}\n{bar}')
# Out:
# ************
# Giulia Mazzi
# ************

# %% [markdown]
# #### Ex 8.4

# %% [markdown]
# ##### Use the methods in this section to strip the whitespace from the following string, which has five spaces at the beginning and end of the string:
# ```python
# name = '     Margo Magenta     '
# ```

# %%
name = '     Margo Magenta     '
name
# Out:
# '     Margo Magenta     '

# %%
name.strip()
# Out:
# 'Margo Magenta'

# %%
name.lstrip()
# Out:
# 'Margo Magenta     '

# %%
name.rstrip()
# Out:
# '     Margo Magenta'

# %% [markdown]
# #### Ex 8.5

# %% [markdown]
# ##### Demonstrate the results of calling `capitalize` and `title` on the string `'happy new year'`.

# %%
test = 'happy new year'
test
# Out:
# 'happy new year'

# %%
test.capitalize()
# Out:
# 'Happy new year'

# %%
test.title()
# Out:
# 'Happy New Year'

# %% [markdown]
# #### Ex 8.7

# %% [markdown]
# ##### Create a loop that locates and displays every word that starts with `'t'` in the string `'to be or not to be that is the question'`.

# %%
for word in 'to be or not to be that is the question'.split():
    if word.startswith('t'):
        print(word, end=' ')
# Out:
# to to that the

# %% [markdown]
# #### Ex 8.8

# %% [markdown]
# ##### Replace the spaces in the string `'1 2 3 4 5'` with `' --> '`.

# %%
'1 2 3 4 5'.replace(' ', ' --> ')
# Out:
# '1 --> 2 --> 3 --> 4 --> 5'

# %% [markdown]
# #### Ex 8.9

# %% [markdown]
# ##### 2. Use `split` and `join` in one statement to reformat the string
# ```python
# 'Pamela White'
# ```
# into the string
# ```python
# 'White, Pamela'
# ```

# %%
', '.join(reversed('Pamela White'.split()))
# Out:
# 'White, Pamela'

# %% [markdown]
# ##### 3. Use `partition` and `rpartition` to extract from the URL string
# ```
# 'http://www.deitel.com/books/PyCDS/table_of_contents.html'
# ```
# the substrings `'www.deitel.com'` and `'books/PyCDS'`.

# %%
url = 'http://www.deitel.com/books/PyCDS/table_of_contents.html'
url
# Out:
# 'http://www.deitel.com/books/PyCDS/table_of_contents.html'

# %%
protocol, separator, rest_of_url = url.partition('://')
host, separator, document_with_path = rest_of_url.partition('/')
host
# Out:
# 'www.deitel.com'

# %%
path, separator, document = document_with_path.rpartition('/')
path
# Out:
# 'books/PyCDS'

# %% [markdown]
# #### Ex 8.12.1

# %% [markdown]
# #####

# %% [markdown]
# #### Ex 8.12.2

# %% [markdown]
# #####

# %% [markdown]
# #### Ex 8.12.3

# %% [markdown]
# #####

# %% [markdown]
# #### Ex 8.13

# %% [markdown]
# #####
