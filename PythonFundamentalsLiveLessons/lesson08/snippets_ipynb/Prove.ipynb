# %% [markdown]
# # Prove

# %%
testo = "\t   \n  This is a test string.   \n\t"
testo
# Out:
# '\t   \n  This is a test string.   \n\t'

# %%
dati = "Amanda: 30, 28, 26"
dati
# Out:
# 'Amanda: 30, 28, 26'

# %%
dati.partition(": ")
# Out:
# ('Amanda', ': ', '30, 28, 26')

# %%
testo = """Linea 1
Linea 2
Linea 3"""

testo
# Out:
# 'Linea 1\nLinea 2\nLinea 3'

# %%
testo.splitlines()  
# ['Linea 1', 'Linea 2', 'Linea 3']
# Out:
# ['Linea 1', 'Linea 2', 'Linea 3']

# %%
testo.splitlines(True)  
# ['Linea 1\n', 'Linea 2\n', 'Linea 3']
# Out:
# ['Linea 1\n', 'Linea 2\n', 'Linea 3']
