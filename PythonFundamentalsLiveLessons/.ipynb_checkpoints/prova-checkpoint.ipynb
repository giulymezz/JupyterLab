# %% [markdown]
# # Questo è il mio Notebook

# %% [markdown]
# ## Questo è il mio notebook

# %% [markdown]
# ### Questo è il mio notebook

# %% [markdown]
# #### Questo è il mio notebook

# %%
45+72
# Out:
# 117

# %%
x = 7

# %%
x + 2
# Out:
# 9

# %%
y = 62

# %%
x + y
# Out:
# 69

# %% [markdown]
# ##### + = Operatore plus, cioè l'operatore di addizione. È uno dei tanti operatori binari di Python (cioè con due operatori, uno a sinistra e uno a destra).

# %%
total = x + y

# %%
total = 69

# %%
6+7
# Out:
# 13

# %%
total2 = 6+7

# %%
total2 + 5
# Out:
# 18

# %%
total3 = x + y

# %%
total3 + total2
# Out:
# 82

# %%
69+13
# Out:
# 82

# %%
x = 4
y = 5

# %%
total5 = x + y

# %%
total5
# Out:
# 9

# %%
type(x)
# Out:
# int

# %%
z = "zeta"

# %%
type(z)
# Out:
# str

# %%
a = True

# %%
type(a)
# Out:
# bool

# %%
b = 12,7

# %%
type(b)
# Out:
# tuple

# %%
type(12,7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 type(12,7)
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(12.7)
# Out:
# float

# %%
c = 12.7

# %%
type(c)
# Out:
# float

# %%
n1 = int(input('Inserisci numero uno'))
# Out:
# Inserisci numero uno 5

# %%
n2 = int(input('Inserisci numero due'))
# Out:
# Inserisci numero due 8

# %%
if n1 == n2:
    print(n1, 'è uguale a', n2)

# %%
if n1 != n2:
    print(n1, 'non è uguale a', n2)
# Out:
# 5 non è uguale a 8

# %%
if n1 == n1:
    print(n1, 'è uguale a', n1)
# Out:
# 5 è uguale a 5
