# %% [markdown]
# # Prove

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.2.4

# %%
import numpy as np

a = np.array([2, 3, 5, 7, 11])
print(a)
print(type(a))
# Out:
# [ 2  3  5  7 11]
# <class 'numpy.ndarray'>

# %%
import numpy as np

b = np.array([[1, 2, 3], [4, 5, 6]])
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]
